# %%
##config box
d = { "key1": "value1", "key2": "value2" }

# %%
d['key1']
# Out:
# 'value1'

# %%
import sys
print(sys.executable)
from box import ConfigBox
print(ConfigBox)
# Out:
# e:\Ravi\GitApps\Kidney-disease-MLFlow-DVC\.venv_na\Scripts\python.exe
# <class 'box.config_box.ConfigBox'>

# %%
d2 = ConfigBox({ "key1": "value1", "key2": "value2" })

# %%
d2.key2
# Out:
# 'value2'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
## ensure annotations

def get_product(x:int,y:int) -> int:
    return x*y

# %%
get_product(2,3)
# Out:
# 6

# %%
get_product(x=2,y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x:int,y:int) -> int:
    return x*y

# %%
get_product(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 get_product(x=2,y="3")
#
# File e:\Ravi\GitApps\Kidney-disease-MLFlow-DVC\.venv_na\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000022C8B2751F0> does not match annotation type <class 'int'>
